# %% [markdown]
# # Lecture 1. Introduction to Python for Machine Learning
#
# - Course Introduction
#     - Ideas, objectives.
#     - Kaggle
#     - Evaluation:
#         - Partial evaluations
#         - Final project
# - Python Fundamentals
#     - [General Python introduction](python-intro.ipynb)
#     - [Sequences](python-sequences.ipynb)
#     - [Dictionaries](python-dictionaries.ipynb)
#     - [Comprehensions](python-comprehensions.ipynb)
#     - [Iterators](python-iterators.ipynb)
#     - [Basic functional programming](python-functional.ipynb)
#     - [Basic object-oriented programming](python-oop.ipynb)
# - Packages
#     - [Introduction to Numpy](python-numpy.ipynb)
#     - [Introduction to Pandas](python-pandas.ipynb)
#     - [Descriptive analysis with Matplotlib and Seaborn](python-matplotlib.ipynb)
